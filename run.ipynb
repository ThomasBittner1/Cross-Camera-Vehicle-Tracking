# %%
import torch
from ultralytics import YOLO
import cv2

# %%
import run
import importlib
importlib.reload(run)
run.run()
# Out:
# EmbeddingGenerator is using: cuda
# SUCCESS  | BotSort: det_thresh=0.3, max_age=30, max_obs=50, min_hits=3, iou_threshold=0.3, per_class=False, asso_func=iou, track_high_thresh=0.25, track_low_thresh=0.1, new_track_thresh=0.25, track_buffer=30, match_thresh=0.8, proximity_thresh=0.5, appearance_thresh=0.8, cmc_method=sof, frame_rate=30, fuse_first_associate=False, with_reid=False
# SUCCESS  | BotSort: det_thresh=0.3, max_age=30, max_obs=50, min_hits=3, iou_threshold=0.3, per_class=False, asso_func=iou, track_high_thresh=0.25, track_low_thresh=0.1, new_track_thresh=0.25, track_buffer=30, match_thresh=0.8, proximity_thresh=0.5, appearance_thresh=0.8, cmc_method=sof, frame_rate=30, fuse_first_associate=False, with_reid=False
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 4
#       2 import importlib
#       3 importlib.reload(run)
# ----> 4 run.run()
#
# ...

# %%
import boxmot
print(boxmot.__file__)
print(dir(boxmot))
# Out:
# C:\ComputerVision\car_multicamera\.venv\lib\site-packages\boxmot\__init__.py
# ['BoostTrack', 'BotSort', 'ByteTrack', 'DeepOcSort', 'HybridSort', 'OcSort', 'ReID', 'SFSORT', 'StrongSort', 'TRACKERS', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'create_tracker', 'engine', 'get_tracker_config', 'motion', 'reid', 'track', 'trackers', 'utils']

# %%
import tracker_compare
import importlib
importlib.reload(tracker_compare)
tracker_compare.run()
# Out:
# SUCCESS  | BotSort: det_thresh=0.3, max_age=30, max_obs=50, min_hits=3, iou_threshold=0.3, per_class=False, asso_func=iou, track_high_thresh=0.25, track_low_thresh=0.1, new_track_thresh=0.25, track_buffer=30, match_thresh=0.8, proximity_thresh=0.5, appearance_thresh=0.8, cmc_method=sof, frame_rate=30, fuse_first_associate=False, with_reid=False
# Frame 950: predicted_ids=[0, 0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# Frame 951: predicted_ids=[0, 0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# Frame 952: predicted_ids=[0, 0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# Frame 953: predicted_ids=[0, 0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# Frame 954: predicted_ids=[0, 0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# Frame 955: predicted_ids=[0, 0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# Frame 956: predicted_ids=[0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# Frame 957: predicted_ids=[0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# Frame 958: predicted_ids=[0, 0, 0, 0, 0, 0] boxmot_track_ids=[1, 2, 3]
# ...
